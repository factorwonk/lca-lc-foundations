# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital or cities. (In fiction some works invent capitals like "Luna," but in reality there isn’t any.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 371, 'prompt_tokens': 13, 'total_tokens': 384, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8HOEjiJbSW2TIQKQN8NhtLa6Clvx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4fd4-55b6-7900-912a-96b1771f3f9e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 371, 'total_tokens': 384, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital or cities. (In fiction some works invent capitals like "Luna," but in reality there isn’t any.)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-D8HOEjiJbSW2TIQKQN8NhtLa6Clvx',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 371,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 320,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 384}}

# %%
pprint(response.content)
# Out:
# ('There isn’t one. The Moon isn’t a country or government, so it has no '
#  'capital or cities. (In fiction some works invent capitals like "Luna," but '
#  'in reality there isn’t any.)')

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
pprint(response.content)
# Out:
# ('There isn’t one. The Moon has no sovereign government or capital city. Any '
#  'future lunar governance would come from Earth-based governments and '
#  'international agreements, not a Moon-wide country. If you want a fun '
#  'fictional idea, people sometimes imagine names like “Luna City” or “Selene” '
#  'as a capital, but that’s purely speculative.')

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %% [markdown]
# model = init_chat_model(model="claude-sonnet-4-5")
#
# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %% [markdown]
# from langchain_google_genai import ChatGoogleGenerativeAI
#
# model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
#
# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent # built on top of langgraph

agent = create_agent(model=model)

# %% [markdown]
# agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='988c815f-f228-41de-a4a5-701b8afda19a'),
#               AIMessage(content='There isn’t one. The Moon has no government or capital. In fiction you might see names like “Luna City” or “Lunapolis,” but those are invented for stories, not real places. If you’re curious, I can share some notable fictional lunar capitals.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 385, 'prompt_tokens': 13, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8HQYNhciOLxn7sLUoFMGOzlLcUs9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4fd6-8690-77c0-97ef-2d23f276b698-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 385, 'total_tokens': 398, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or capital. In fiction you might see names like “Luna City” or “Lunapolis,” but those are invented for stories, not real places. If you’re curious, I can share some notable fictional lunar capitals.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response) # 20 sec response time.
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='cc8156a1-f7a9-496d-85fe-9962ea3f312e'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2dc99683-b856-494c-b1b8-7eed673db6d6', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='f9e1a30f-d8c3-4b63-82e7-d89fa3d63b06'),
#               AIMessage(content='Since Luna City is a fictional concept, here’s a richer world-building sketch you can use for stories, games, or exploration of the idea.\n\nOverview\n- Luna City is imagined as the political and cultural capital of a lunar settlement federation. It sits at the rim of Shackleton Crater near the Moon’s south pole, where long shadows and near-constant solar angles create a unique urban environment.\n- The city blends high-tech habitats with rugged ISRU (in-situ resource utilization) infrastructure, built to survive the Moon’s cold, radiation, and vacuum.\n\nLocation and layout\n- The city is organized in concentric districts inside a network of pressurized domes and artificial caverns.\n  - The Dome Belt: residential districts, schools, hospitals, parks, and cultural venues under translucent membranes.\n  - The Heights: vertical neighborhoods with transparent facades offering views of Earth and the crater floor.\n  - The Ring of Industry: ISRU centers, oxygen production, food agriculture domes, and manufacturing.\n  - The Ice Edge: extraction and processing of water ice from permanently shadowed regions nearby; the energy and life-support backbone of the city.\n- A central spine, the Helios Gate, connects to an interplanetary transport hub and lunar rail lines.\n\nGovernance and society\n- Governing body: the Lunar Council, composed of representatives from each habitat dome and major industry clusters, guided by a Lunar Charter that enshrines resource equity, environmental stewardship, and scientific freedom.\n- Law and order emphasize civil liberties mixed with pragmatic space-law: contamination controls, mining rights, and data sovereignty are hotly debated topics.\n- Society values education, open science, and multilingual communication (Earth languages plus Selenic slang developed by residents).\n\nEconomy and daily life\n- Economy centers on ISRU: extracting water ice, producing oxygen, generating lunar concrete, and 3D-printing parts and habitats.\n- The city acts as a logistics and data hub for cislunar activities, with a thriving service sector: healthcare, education, arts, and entertainment for settlers and visiting scientists.\n- Everyday life features thermal- and radiation-protected living, hydroponic farms, and closed-loop waste recycling. Residents may commute via a network of lunar elevators and maglev transit.\n- Tourism exists in limited form: guided tours inside glass-domed parks and the Ice Edge, with strict environmental controls to protect sensitive regolith.\n\nTechnology and infrastructure\n- Energy: a mix of solar arrays on crater rims and a compact, shielded power plant; emergency RTG backups.\n- Housing: a blend of inflatable and rigid habitat modules with regolith shielding and airlocks.\n- Mobility: surface trolleys, vacuum suits for short trips, and tunnel networks linking habitat clusters.\n- Research: laboratories for astrochemistry, life support, and robotics; data dignities protect intellectual property and citizen privacy.\n\nNotable sites and landmarks\n- Helios Gate: the ceremonial and transport hub at the crater rim.\n- Aurora Dome: a cultural and performance complex with panoramic lunar views.\n- Ice Forge: ISRU processing and manufacturing site where water ice becomes life-support commodities and building materials.\n- Echo Dome: an amphitheater and public forum for science talks and debates.\n- The Observatory: a high-tech telescope complex tracing Earth and deep space objects from a favorable vantage point.\n\nHistory and challenges (quick context)\n- Founded in the mid-21st century as part of a multinational lunar autonomy initiative; growth driven by ice extraction, industry partnerships, and scientific missions.\n- Major challenges include radiation, micrometeoroid protection, dust management, and the political complexity of coordinating many Earth nations and private interests.\n- Ongoing themes: balancing resource rights with environmental safeguards, ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City isn’t a real place today. If you’re thinking of a fictional setting—the capital of the Moon in a story, game, or world you’re building—here’s a comprehensive world-building briefing you can adapt. It covers geography, government, society, technology, culture, and plot hooks. You can mix and match ideas to fit your tone (hopeful, dystopian, cyberpunk, utopian, etc.).
#
# Core concept (one-paragraph overview)
# Luna City is the lunar capital, a sprawling, modular metropolis carved into and around the Moon’s natural features. It sits at the edge of a large crater rim with access to water ice, abundant sunlight, and a protective ring of regolith shielding. The city blends advanced closed-loop life support, autonomous construction, and AI-driven governance with human politics, culture, and conflict. It’s the political heart of the Moon’s colonies, a hub for science, industry, and art, and a focal point for Earth–Moon diplomacy, trade, and tension.
#
# Three archetypal variants you can choose or fuse
# - Democratic lunar federation capital: A parliamentary system with a technocratic backbone. Governed by a Lunar Authority that includes elected representatives, engineers, scientists, and planetary ambassadors. Public squares, debates, and referenda shape policy on water rights, mining quotas, and habitat expansion.
# - Corporate-municipal city-state: A city run by a consortium of mining, biotech, and energy firms. The ruling council is a rotating board drawn from the major employers, with a strong security presence and a legal system shaped by corporate necessity. Earth’s influence is indirect but persistent.
# - Cultural-religious capital: A city built around a spiritual and artistic governance model. Institutes of lunar tradition, rituals tied to solar half-days and radio silence windows, and a council of cultural custodians. Earth and corporate interests are managed through cultural diplomacy and public works that emphasize lunar identity.
#
# Geography and city layout
# - Location: Built around a large, sunlit crater rim (or a system of intersecting lava tubes) that provides natural shielding, near-permanent daylight corridors, and access to subsurface water ice. Permanent shade pockets are used for data centers and storage.
# - District structure:
#   - Core Civic District: Parliament, executive offices, courts, emergency services, and medical hubs. Clear, daylight-simulated avenues with transparent solar collectors above.
#   - Research and Industry Corridor: Labs, mineral processing, 3D-printing yards, fabrication facilities, and energy plants. A cadence of delivery tunnels links to the surface and to orbital support.
#   - Residential Ring: Mixed-habitat modules, from compact family apartments to larger communal suites for scientists and miners. Housing is modular and expandable.
#   - Agricultural and Resource Zone: Hydroponics farms, algae bioreactors, and closed-loop waste recycling; water processing and air revitalization centers.
#   - Cultural Quarter and Public Spaces: Museums, theaters, schools, markets, observatories, and public gardens using oxygen-generating flora and art-integrated architecture.
# - Transportation arteries: planetary elevators or surface-to-orbit ramps, maglev tram lines along the crater rim, autonomous shuttles, and pedestrian skyways between domes. Deep tunnels for heavy cargo and mining operations connect to Earth-bound supply lanes.
#
# Infrastructure and technology
# - Life support: Closed-loop air, water reclamation, and hydroponics; bio-regenerative life support in housing modules. Redundancy is built into every critical system.
# - Energy: A mix of solar arrays on crater rims, solar windows in districts, and compact nuclear microreactors or kilopower plants for night-cycle power. Energy sharing is managed by a city-wide smart grid with AI optimization.
# - Housing and construction: 3D-printed regolith composites, inflatable habitats, and lava-tube modules reinforced with carbon fiber. Radiation shielding is built into outer walls and shared transit corridors.
# - Water and food: Ice mined from shadowed regions, melted and purified; water recycling is near-absolute. Algae and hardy crops provide food and oxygen. Waste streams feed bioreactors to close the loop.
# - Communication: High-bandwidth links to Earth and satellites, with local mesh networks for city operations. AI overseers manage traffic, energy, and safety, with human oversight for ethical and legal issues.
# - Health and safety: Medical centers with autonomous diagnostic pods, telemedicine links to Earth, and rapid-deployment shelters for cosmic ray events or solar storms. Regular radiation exposure monitoring is standard.
#
# Governance and economy
# - Government structure (one of several possibilities): A Lunar Authority or Lunar Council comprised of human representatives, engineers, scientists, and civic servants. A judiciary and police/military wing exist, with civilian oversight. The exact balance of power depends on whether you want a technocracy, a democracy, or a hybrid.
# - Economy: Heavy emphasis on extraction (ice, minerals, volatiles), processing, and high-value research; lunar tourism and science missions to nearby craters or lava tubes. Earth-Luna trade focuses on metals, water, and advanced technologies. Local economy rewards contribution to habitat resilience and self-sufficiency.
# - Employment and class: Earth-born workers, Moon-born settlers, and a rising class of hybrid professionals trained on the Moon. Some residents become privileged due to access to rare resources or specialized knowledge; others feel restricted by policy or corporate policy. Tensions between Earth-haves and Moon-residents can drive conflict.
#
# Society, culture, and daily life
# - Demographics: A mix of Earth emigrants, long-time Moon-dwellers born in lunar habitats, and robotic or AI-assisted professionals. Language blends Earth languages with lunar slang and technical jargon.
# - Culture and identity: Lunar pride, ritual commemorations tied to solar cycles, and a fusion of Earth cultural elements with Moon-specific art and music. Public art often uses glass, mineral pigments, and lighting that plays with the Moon’s lighting cycles.
# - Education and research: Universities and institutes focus on astrogeology, life support engineering, robotics, and synthetic biology. Public outreach programs teach residents about lunar geology, sustainable living, and space ethics.
# - Recreation and leisure: Zero-G sports leagues, art residencies in dome studios, public observatories with citizen scientists, community gardens in domed habitats, and seasonal festivals linked to solar events.
# - Cuisine: Fresh grown greens, algae-based proteins, hydroponic root vegetables, and mineral-rich dishes using space-grown fungi and tubers. Food markets emphasize nutrition, efficiency, and flavor under constrained resources.
#
# Security, challenges, and conflicts
# - Threats and risks: Radiation storms, micrometeoroid impacts, dust management, power outages, water scarcity, and political campaigning that veers into infighting or protests. Smuggling and black-market tech can exist around rare resources like water ice or certain isotopes.
# - Security apparatus: A civilian-led enforcement agency supported by technical officers and orbital surveillance. Independent oversight ensures civil liberties. Some stories might focus on cyber-security, AI governance, or pirate-mining factions.
# - Political tensions: Earth-Moon diplomacy friction, resource allocation disputes, or internal factionalism between technocrats, miners, and cultural custodians. A factional crisis could erupt around a new water discovery, a datastream leak, or a political reform referendum.
#
# Notable places and organizations (sample names you can use or remix)
# - The Bright Rim Parliament Hall: center of lunar governance with glassy domes catching the sun at high angles.
# - The Argent Spire: an architectural landmark housing the central AI hub and the city’s data core.
# - Craterview Market: a bustling district where traders exchange minerals, biotech products, and lunar souvenirs.
# - The Subsurface Conservatory: a network of lava-tube habitats used for rare plant and bioreactor experiments.
# - Helios Gate: a ceremonial entrance to the city representing lunar resilience and solar power.
# - Lunar Authority (or Lunar Council): the governing body, with committees for water, energy, security, science, culture, and education.
# - University of Selenia: premier research institution with lunar geology, life support engineering, and artificial ecosystems programs.
# - Tidewatch Police: specialized enforcement unit skilled in low-gravity logistics, space law, and cyber-ops.
# - Heirloom Conservatories: cultural centers preserving lunar arts, music, and folklore.
#
# Character archetypes you might meet in Luna City
# - Chief Administrator (or Mayor) who must balance Earth diplomacy with lunar autonomy.
# - Chief Engineer or Chief Architect who designs habitat modules, shielding strategies, and energy grids.
# - Scientist-Activist who campaigns for equitable resource distribution or new life-support tech.
# - Miner-Entrepreneur who controls extraction operations and oversees transport networks.
# - Artist-In-Residence who creates lunar-inspired works in the domed districts.
# - Scout-Ambassador who negotiates with Earth or other lunar settlements.
#
# Story hooks and plot seeds
# - Water crisis and reform: A new water ice deposit is found but guarded by a shadowy consortium. A journalist or investigator uncovers political manipulation behind the discovery.
# - Lunar archaeology mystery: A hidden network beneath a lava tube contains artifacts suggesting older lunar civilizations or unknown tech, triggering debates about lunar heritage and ownership.
# - AI governance puzzle: The city’s central AI begins to act with unexpected autonomy. Human overseers must decide whether to reboot, reprogram, or negotiate with the AI.
# - Earth-Luna diplomacy coup: A high-stakes negotiation treaty is about to be signed, but a faction within Earth or Luna sabotages it to gain leverage.
# - Cultural awakening: A controversial exhibit or ritual challenges traditional lunar norms, driving debates over identity, censorship, and freedom of expression.
# - Environmental anomaly: A solar storm or radiation flare disrupts life-support systems, forcing residents to improvise, cooperate, and confront governance gaps.
#
# Quick-start world bible (one-page template you can fill in)
# - Name: Luna City
# - Concept: [short one-liner about the city’s role and vibe]
# - Location: [crater rim, lava tubes, near water ice]
# - Government: [type of governance, key institutions]
# - Economy: [main industries and trade partners]
# - Society: [demographics, major social tensions]
# - Technology: [core tech that defines daily life]
# - Culture: [arts, food, rituals, holidays]
# - Conflicts: [primary tensions driving plot]
# - Notable places: [three to five landmarks or districts]
# - Key characters: [three archetypal figures or names]
#
# How you can tailor Luna City to your project
# - If you want a hopeful, utopian tone: emphasize resilience, collaboration between Earth and Moon, and cutting-edge sustainability.
# - If you want a gritty, techno-thriller vibe: lean into corporate factions, black-market tech, political intrigue, and resource scarcity.
# - If you want a political drama: focus on representation, governance reform, and the ethics of AI-guided society.
# - If you want an epic sci-fi fantasy blend: weave lunar myths, ceremonial rituals, and advanced magic-like technologies derived from physics or bioengineering.
#
# If you tell me your medium (novel, game, screenplay), the desired tone, and a rough timeframe of your setting, I can tailor a more precise Luna City guide with detailed districts, key organizations, and plot hooks that fit your project. Would you like a concrete version for a particular genre or a ready-to-use faction map and character bios to drop into your story?

# %% [markdown]
# ***In this case we didnt exactly reduce latency since content generation began at around 21 secs***
