# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool # initialise web search tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]}, # Test out agent performance
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice are a perfect base for a bunch of tasty meals. Here are some quick ideas you can try, plus a note on what you’d need to add if you want to pull them from a specific recipe.
#
# 1) Chicken Fried Rice
# - What it is: A fast, skillet-cooked dish that revives both chicken and rice with soy sauce, a little sesame oil, and eggs.
# - Quick version: Sauté onion/garlic, push aside; scramble a couple eggs, mix in shredded chicken and cold rice, add peas/carrots, splash soy sauce and a drizzle of sesame oil. Top with green onions.
# - Time: about 20 minutes.
#
# 2) One-Pot Chicken and Rice
# - What it is: A comforting, all-in-one skillet meal with chicken, rice, and stock.
# - Quick version: Sauté onion/garlic, stir in rice and broth, simmer until just tender, then fold in shredded chicken and quick veggies (peas, carrots) for a few final minutes.
# - Time: 30–40 minutes.
#
# 3) Arroz Con Pollo (Latin-style chicken and rice)
# - What it is: A flavorful one-pan dish with rice, tomatoes, peppers, and spices.
# - Quick version: Brown chicken pieces (optional), sauté aromatics and bell peppers, add rice, stock, tomatoes, and spices (saffron, paprika, or jealousy-of-adobo seasoning); simmer until rice is tender and chicken is heated through; toss in peas at the end.
# - Time: 40 minutes.
#
# 4) Creamy Chicken and Rice Casserole
# - What it is: A cozy bake with chicken, rice, and a creamy cheese or soup-based sauce.
# - Quick version: Mix shredded chicken, cooked rice, cream of chicken soup (or a homemade cream sauce), a little milk, and cheese; bake until bubbly and golden.
# - Time: 40 minutes (plus bake time).
#
# 5) Hearty Chicken and Rice Soup
# - What it is: A warming soup with chicken, rice, and veggies in a soothing broth.
# - Quick version: Start with onions, carrots, celery; add chicken stock and seasonings, simmer briefly; add shredded chicken and rice last so it doesn’t get mushy; finish with herbs.
# - Time: about 30–40 minutes.
#
# 6) Cheesy Chicken Rice Skillet (weeknight friendly)
# - What it is: A quick skillet bake with veggies and cheese.
# - Quick version: Sauté aromatics, mix in rice, add a little broth to loosen, fold in chicken and your favorite veggies, top with cheese and finish under a brief broil or lid-covered melt.
# - Time: ~25–35 minutes.
#
# Tips to tailor to what you have:
# - Veggies: peas, carrots, corn, bell peppers, onions, garlic, green onions.
# - Flavor boosters: soy sauce, teriyaki, paprika, cumin, saffron (or turmeric as a budget-friendly stand-in), cream of chicken soup or a splash of cream/milk for casseroles.
# - Spices: salt, pepper, garlic powder, onion powder, chili flakes if you want heat.
# - Dairy/cheese: cream, cream cheese, shredded cheddar or mozzarella for casseroles or skillet melts.
#
# Would you like me to pull a full, step-by-step recipe for any of these? If yes, tell me which dish you want and how many servings you need, and I’ll fetch a specific recipe and adapt it to your leftovers.

# %%
from pprint import pprint
# Message by message breakdown of the agent's response, including tool calls and final answer:
pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='5a2d5b3f-8b65-490b-8ef9-7c0ad43b53f3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 569, 'prompt_tokens': 199, 'total_tokens': 768, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eL0Tnj2LjomkfxxWIQ3wTaKNQkZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c5516-58e3-76b2-a5a7-52a976ad3a69-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_VLPliJ951RvlCSMPcKDToJj8', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_bKqjJ2nI56OLrDtjSnfQj6af', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'one-pot chicken and rice recipe'}, 'id': 'call_PWLA0SVy3FanK5z4njaDNwUK', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe'}, 'id': 'call_jppL7U3XV0FZwcyy139TUHLS', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'arroz con pollo recipe with leftover chicken'}, 'id': 'call_iSS4KmJRW6Y7lXuwUoGc1pKA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 569, 'total_tokens': 768, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Let it cook for 7 hrs low. Shred the chicken and mix the veggies. Then add your rice. Submerge the rice. Let cook on low for 30 mins. Check rice", "score": 0.8827621, "raw_content": null}, {"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Dice the leftover chicken while boiling the rice. Put a cup of milk in a saucepan and add a can of cream of chicken soup. As milk/soup mixture", "score": 0.87166095, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Ingredients · 2 tablespoons olive, rapeseed or coconut oil · 300-500 g leftover chicken shredded · 500 g pre-cooked brown rice · 100 g frozen peas · 100 g frozen", "score": 0.8449346, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.81418616, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Recipe Video. Prep Time 10 minutes minutes. Cook Time 25", "score": 0.78054583, "raw_content": null}], "response_time": 0.73, "request_id": "e70675e3-3827-4665-ad18-d89996f4a093"}', name='web_search', id='465b0c8f-6ab1-4a5e-9a9e-f8ee48c95029', tool_call_id='call_VLPliJ951RvlCSMPcKDToJj8'),
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.delish.com/cooking/recipe-ideas/a25635966/chicken-fried-rice-recipe/", "title": "Best Chicken Fried Rice Recipe", "content": "This classic take on chicken fried rice is too easy to make (and customize) for the perfect make-ahead lunch or dinner.", "score": 0.99988854, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/16954/chinese-chicken-fried-rice-ii/", "title": "Chicken Fried Rice Recipe", "content": "This chicken fried rice recipe is very easy to make and tastes better than takeout! It\'s basically cooked chicken, rice, soy sauce, and shredded egg stir-fried", "score": 0.9998634, "raw_content": null}, {"url": "https://www.recipetineats.com/chicken-fried-rice/", "title": "Chicken Fried Rice", "content": "A fully loaded, fabulous Chicken Fried Rice! With seasoned chicken, vegetables, fluffy egg and pops of salty bacon, this fried rice recipe is one that\'s worthy", "score": 0.99983394, "raw_content": null}, {"url": "https://www.averiecooks.com/easy-better-takeout-chicken-fried-rice/", "title": "Easy Better-Than-Takeout Chicken Fried Rice", "content": "Easiest Fried Rice Recipe with Chicken · It\'s an easy, one-skillet recipe that\'s ready in 20 minutes and better than takeout. · The chicken is", "score": 0.99972624, "raw_content": null}, {"url": "https://iowagirleats.com/take-out-fake-out-easy-chicken-fried-rice/", "title": "Easy Chicken Fried Rice", "content": "Easy Chicken Fried Rice is a cinch to make at home with a few kitchen staples. This simple, 20 minute dish tastes just like take out!", "score": 0.99972624, "raw_content": null}], "response_time": 0.89, "request_id": "7e1e8f25-4dad-4b98-948e-d7dd45798330"}', name='web_search', id='178bd28e-e181-4cc1-8e9e-e21701038fcb', tool_call_id='call_bKqjJ2nI56OLrDtjSnfQj6af'),
#               ToolMessage(content='{"query": "one-pot chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.cookincanuck.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Cookin Canuck", "content": "# One Pot Chicken and Rice. Serve this delicious one pot chicken and rice recipe with a big green salad or a side of steamed vegetables for a healthy dinner the whole family will love.*. One Pot Chicken and Rice is one of those recipes we turn to again and again. ## INGREDIENTS FOR THIS ONE POT CHICKEN RICE RECIPE:. ## How to make one pot chicken and rice:. In the original recipe, the chicken is added after the rice simmers for about 25 minutes. Allow them to steam in the covered skillet while the rice and chicken finish cooking. ## One Pot Chicken and Rice. Serve this delicious one pot chicken and rice recipe with a big green salad or a side of steamed vegetables for a healthy dinner this week. * Stir the brown rice and chicken broth into the vegetables. The rice should be tender and the chicken cooked through.", "score": 0.926683, "raw_content": null}, {"url": "https://www.reddit.com/r/recipes/comments/zf52y0/onepot_chicken_and_rice/", "title": "One-Pot Chicken and Rice : r/recipes - Reddit", "content": "Add water or chicken stock and bring to a boil. Place chicken on top, reduce heat to low, cover, and simmer for 20–25 minutes.", "score": 0.91156644, "raw_content": null}, {"url": "https://www.facebook.com/DavenGatesOSC/posts/one-pot-chicken-and-rice-is-probably-my-go-to-weeknight-quick-meal/923308090267713/", "title": "One Pot Chicken and Rice is probably my go to weeknight quick meal.", "content": "FULL RECIPE HERE: Ingredients Chicken • 4–5 bone-in chicken thighs • 4–5 bone-in chicken legs (drumsticks) • 2 tbsp oil (olive or avocado)", "score": 0.9014448, "raw_content": null}, {"url": "https://www.simplyrecipes.com/one-pot-chicken-and-rice-recipe-8765045", "title": "My Mom\'s One-Pot Chicken and Rice Is Pure Comfort Food", "content": "# My Mom’s One-Pot Chicken and Rice Is Pure Comfort Food. This simple dish of shredded chicken and creamy rice is like a warm hug. * One-pot chicken and rice is a cozy, homey dish — minimal fuss, maximum comfort. For me, that dish is chicken and rice—specifically *this* chicken and rice. Of course, “my” chicken and rice is by no means anything new (many cultures around the world have variations on the theme), but it is the dish I most often request when I return home. ## Simple One-Pot Chicken and Rice Variations. * 3-Ingredient Banana Pepper Chicken. ## One-Pot Chicken and Rice. Feel free to make this dish with any boneless, skinless chicken you have on hand, but the convenience of frozen, bagged tenders means they can go straight from the freezer to the boiling pot. Add the salt followed by the chicken tenders and boil, uncovered, until mostly cooked through, about 10 minutes. Instant Pot Chicken and Rice.", "score": 0.8914433, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/282524/one-pot-crispy-chicken-and-rice/", "title": "One-Pot Crispy Chicken and Rice - Allrecipes", "content": "Ingredients · 1 tablespoon olive oil · 6 (4 ounce) bone-in, skin-on chicken thighs · 1 ½ teaspoons kosher salt, divided · ¾ teaspoon ground black pepper · 1", "score": 0.86358756, "raw_content": null}], "response_time": 0.94, "request_id": "47086e4b-eb9b-4513-bb75-45574a9b80b4"}', name='web_search', id='dbdbe28c-3d4d-431f-b928-cc34a4b8d493', tool_call_id='call_PWLA0SVy3FanK5z4njaDNwUK'),
#               ToolMessage(content='{"query": "chicken and rice soup recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.simplyrecipes.com/recipes/one_pot_chicken_and_rice_soup/", "title": "One-Pot Chicken and Rice Soup - Simply Recipes", "content": "Combine the chicken, white rice, celery, carrots, onions, garlic, salt, and pepper in a large pot. Add the chicken stock and bring to a boil over high heat.", "score": 0.92763275, "raw_content": null}, {"url": "https://www.acouplecooks.com/chicken-and-rice-soup-recipe/", "title": "Chicken and Rice Soup (Family Favorite!) - A Couple Cooks", "content": "Add the chicken stock, water, whole chicken breasts, rice, oregano, garlic powder, and kosher salt. Bring to a boil, then reduce to a simmer.", "score": 0.91795975, "raw_content": null}, {"url": "https://www.seriouseats.com/classic-chicken-and-rice-soup-recipe-11825083", "title": "Classic Chicken and Rice Soup - Serious Eats", "content": "# Classic Chicken and Rice Soup. * Poaching chicken leg meat separately from the soup base ensures perfectly cooked meat and eliminates a lot of the guesswork involved with building the soup in one pot. I’m a sucker for Progresso’s Chicken Rice Soup (With Vegetables). You would think making a proper chicken and rice soup is straightforward, but in practice it’s a little tricky. Instead of water, I cook the rice in a measured amount of reserved leg-poaching liquid—straight out of the Hainanese chicken rice playbook. Chicken-flavored rice, which means even more chicken flavor in the finished soup. ## Classic Chicken and Rice Soup. To make ahead, prepare recipe through Step 7; store chicken, broth, and cooked rice separately in refrigerator for up to 1 week or frozen for up to 3 months. Arroz Caldo (Filipino Chicken and Rice Soup). Creamy Chicken and Wild Rice Soup. Samgyetang (Korean Rice-Stuffed Chicken Soup) Recipe. Easy Chicken and Ginger Soup With Rice Cakes, Chives, and Quick-Pickled Garlic Recipe.", "score": 0.8808076, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/231291/hearty-chicken-and-rice-soup/", "title": "Hearty Chicken and Rice Soup Recipe - Allrecipes", "content": "This flavorsome chicken and rice soup with veggies, fluffy rice, and tender chunks of chicken is ready in just over 30 minutes for a cozy", "score": 0.8576849, "raw_content": null}, {"url": "https://kristineskitchenblog.com/chicken-and-rice-soup/", "title": "Best Chicken and Rice Soup - Kristine\'s Kitchen", "content": "This chicken and rice soup is filled with tender chicken, rice and vegetables in a flavorful broth. Make it with brown rice, white rice or wild rice.", "score": 0.85097736, "raw_content": null}], "response_time": 0.74, "request_id": "397a6702-8ec0-425a-9306-df31035a5068"}', name='web_search', id='228ade78-565e-4618-8a0d-0eb4e0fdff6a', tool_call_id='call_jppL7U3XV0FZwcyy139TUHLS'),
#               ToolMessage(content='{"query": "arroz con pollo recipe with leftover chicken", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://ethnicspoon.com/arroz-con-pollo/", "title": "Easy Authentic Arroz con Pollo Recipe – Latin Chicken & Rice", "content": "A way to use leftovers ... By the way arroz con pollo also makes a great leftover meal. Yeah, it\'s great the next day warmed up in the microwave.", "score": 0.99998844, "raw_content": null}, {"url": "https://www.facebook.com/groups/841101977550933/posts/845303043797493/", "title": "Arroz con pollo recipe with leftover chicken - Facebook", "content": "In a large pot, heat olive oil over medium-high heat. Brown the chicken pieces on all sides, then remove and set aside. In the same pot, add the", "score": 0.9999671, "raw_content": null}, {"url": "https://simple-nourished-living.com/weight-watchers-easy-arroz-con-pollo-chicken-with-rice/", "title": "Weight Watchers Easy Arroz Con Pollo (Chicken with Rice)", "content": "This easy arroz con pollo is a quick and easy one-pot variation using leftover cooked chicken that can be made in about 30 minutes.", "score": 0.9999329, "raw_content": null}, {"url": "https://www.laylita.com/recipes/latin-style-rice-with-chicken-or-turkey/", "title": "Latin style rice with chicken or turkey {Arroz con pollo o pavo}", "content": "An easy recipe for Latin style rice with chicken or turkey, also known as arroz con pollo o pavo, to use up roasted chicken or turkey leftovers.", "score": 0.99992156, "raw_content": null}, {"url": "https://www.theingredientthief.com/post/easy-arroz-con-pollo-chicken-rice", "title": "Easy Arroz Con Pollo (Chicken & Rice) - The Ingredient Thief", "content": "# Easy Arroz Con Pollo (Chicken & Rice). To me, a hot bowl of Chicken and Rice is the ultimate comfort food. This Arroz con Pollo uses store bough Rotisserie Chicken, Seasoned Rice, Frozen Veggies and a few pantry staples. There are much more detailed recipes for Arroz Con Pollo, and I do like to make them, but this is a great go-to recipe that will taste like you have been cooking it for hours! * 1 store bought organic rotisserie chicken, skin removed, meat shredded. * 2/3 cup chicken stock. 1. Cook the rice according to package instructions. 2. Add chicken to a bowl and toss with 1.5 tbsp adobo seasoning. Add Chicken and heat until hot and slightly browned. 4. Add chicken stock and frozen veggies, continue to cook until vegetables are heated and all the liquid is absorbed. Add the remaining adobo seasoning. 5. Once rice is cooked and rested add to the chicken mixture.", "score": 0.99987364, "raw_content": null}], "response_time": 0.93, "request_id": "2b2adc55-5eae-42f6-88dc-76c966561114"}', name='web_search', id='59c03dbd-11cb-40ee-8ebd-c817ab470bac', tool_call_id='call_iSS4KmJRW6Y7lXuwUoGc1pKA'),
#               AIMessage(content='Nice! Leftover chicken and rice are a perfect base for a bunch of tasty meals. Here are some quick ideas you can try, plus a note on what you’d need to add if you want to pull them from a specific recipe.\n\n1) Chicken Fried Rice\n- What it is: A fast, skillet-cooked dish that revives both chicken and rice with soy sauce, a little sesame oil, and eggs.\n- Quick version: Sauté onion/garlic, push aside; scramble a couple eggs, mix in shredded chicken and cold rice, add peas/carrots, splash soy sauce and a drizzle of sesame oil. Top with green onions.\n- Time: about 20 minutes.\n\n2) One-Pot Chicken and Rice\n- What it is: A comforting, all-in-one skillet meal with chicken, rice, and stock.\n- Quick version: Sauté onion/garlic, stir in rice and broth, simmer until just tender, then fold in shredded chicken and quick veggies (peas, carrots) for a few final minutes.\n- Time: 30–40 minutes.\n\n3) Arroz Con Pollo (Latin-style chicken and rice)\n- What it is: A flavorful one-pan dish with rice, tomatoes, peppers, and spices.\n- Quick version: Brown chicken pieces (optional), sauté aromatics and bell peppers, add rice, stock, tomatoes, and spices (saffron, paprika, or jealousy-of-adobo seasoning); simmer until rice is tender and chicken is heated through; toss in peas at the end.\n- Time: 40 minutes.\n\n4) Creamy Chicken and Rice Casserole\n- What it is: A cozy bake with chicken, rice, and a creamy cheese or soup-based sauce.\n- Quick version: Mix shredded chicken, cooked rice, cream of chicken soup (or a homemade cream sauce), a little milk, and cheese; bake until bubbly and golden.\n- Time: 40 minutes (plus bake time).\n\n5) Hearty Chicken and Rice Soup\n- What it is: A warming soup with chicken, rice, and veggies in a soothing broth.\n- Quick version: Start with onions, carrots, celery; add chicken stock and seasonings, simmer briefly; add shredded chicken and rice last so it doesn’t get mushy; finish with herbs.\n- Time: about 30–40 minutes.\n\n6) Cheesy Chicken Rice Skillet (weeknight friendly)\n- What it is: A quick skillet bake with veggies and cheese.\n- Quick version: Sauté aromatics, mix in rice, add a little broth to loosen, fold in chicken and your favorite veggies, top with cheese and finish under a brief broil or lid-covered melt.\n- Time: ~25–35 minutes.\n\nTips to tailor to what you have:\n- Veggies: peas, carrots, corn, bell peppers, onions, garlic, green onions.\n- Flavor boosters: soy sauce, teriyaki, paprika, cumin, saffron (or turmeric as a budget-friendly stand-in), cream of chicken soup or a splash of cream/milk for casseroles.\n- Spices: salt, pepper, garlic powder, onion powder, chili flakes if you want heat.\n- Dairy/cheese: cream, cream cheese, shredded cheddar or mozzarella for casseroles or skillet melts.\n\nWould you like me to pull a full, step-by-step recipe for any of these? If yes, tell me which dish you want and how many servings you need, and I’ll fetch a specific recipe and adapt it to your leftovers.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2263, 'prompt_tokens': 3817, 'total_tokens': 6080, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1536, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eL85J1FKXlR2UMTjgrym06VeZCm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5516-777d-7481-ab4d-77c773f06986-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3817, 'output_tokens': 2263, 'total_tokens': 6080, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1536}})]}

# %% [markdown]
# * From the module-1 working directory open terminal and type in `uv run langgraph dev`
#
# * REQUIRES A LANGSMITH ACCOUNT
