# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# I don’t have real-time knowledge. My training data goes up to about November 2023, and I don’t automatically browse the web unless you enable browsing or a plugin.
#
# What that means:
# - I can answer based on information available up to roughly Nov 2023.
# - I may miss recent events, discoveries, or updates after that date.
# - If you need current info, you can provide sources or I can use browsing plugins if you enable them.

# %%
question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# London Breed.
#
# She has been San Francisco’s mayor since 2018 and was re-elected in 2022, with her current term running through 2027. If you’d like, I can check a real-time source to confirm the latest status.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9996699,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9979966,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.993255,
#    'raw_content': None},
#   {'url': 'https://www.commonwealthclub.org/events/archive/video/mayor-daniel-lurie-people-are-betting-san-francisco-again',
#    'title': 'Mayor Daniel Lurie: “People Are Betting on San Francisco Again”',
#    'content': 'When Daniel Lurie was sworn in as San Francisco\'s 46th mayor in January, he called for "the beginning of a new era of accountability and',
#    'score': 0.9837225,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/profile--daniel-lurie',
#    'title': 'Daniel Lurie - SF.gov',
#    'content': "Chair, and Mayor of San Francisco. Disaster Council · Office of the Mayor. Mayor Daniel Lurie sworn in as the City's 46th mayor on Jan 8. See recent news. Learn",
#    'score': 0.9755769,
#    'raw_content': None}],
#  'response_time': 1.16,
#  'request_id': '6e83beff-0bf8-4025-8aa3-2137f72c7355'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='f44047b4-cce0-45cf-ba9f-860d62809774'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 133, 'total_tokens': 480, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8K0FARJ6Imner2aUs4v4uEHk3FTz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c506d-9c4c-7171-89cb-7741ae06f57b-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'call_0LrkSjJXO0OS30U2tuWVzAf1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 347, 'total_tokens': 480, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.99916387, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.99596137, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco.", "score": 0.98657167, "raw_content": null}, {"url": "https://www.npr.org/2024/11/24/nx-s1-5190796/san-franciscos-incoming-mayor-has-never-held-public-office-thats-part-of-his-appeal", "title": "San Francisco\'s incoming mayor has never held public office ... - NPR", "content": "Daniel Lurie is the first person in nearly a century to be elected mayor without prior experience in City Hall. Lurie defeated Mayor London", "score": 0.9861514, "raw_content": null}, {"url": "https://www.sf.gov/profile--daniel-lurie", "title": "Daniel Lurie - SF.gov", "content": "Chair, and Mayor of San Francisco. Disaster Council · Office of the Mayor. Mayor Daniel Lurie sworn in as the City\'s 46th mayor on Jan 8. See recent news. Learn", "score": 0.9683812, "raw_content": null}], "response_time": 0.63, "request_id": "724868fe-3a2e-4539-95eb-305d9840c991"}', name='web_search', id='d4b4fd22-cebf-44eb-ad96-5c14509f9b4f', tool_call_id='call_0LrkSjJXO0OS30U2tuWVzAf1'),
#  AIMessage(content='Daniel Lurie. He was sworn in as the 46th mayor of San Francisco on January 8, 2025. \n\nSources: SF.gov — Office of the Mayor; SF.gov profile for Daniel Lurie.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1270, 'prompt_tokens': 676, 'total_tokens': 1946, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8K0KIzaFsAMpeC5XKsKcDCvzNvuD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c506d-b1c5-7b80-b806-5a89b1be5c57-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 676, 'output_tokens': 1270, 'total_tokens': 1946, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
