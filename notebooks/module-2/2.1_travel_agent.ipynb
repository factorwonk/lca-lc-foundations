# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='202ef7e5-1376-4e55-8209-8503487b11f3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1929, 'prompt_tokens': 1229, 'total_tokens': 3158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1856, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8q3lj7g2C9jNdZaId9nzdjFGkkof', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c57c5-e422-7733-9d8e-cfa069bd5f22-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'passengers': {'adults': 1}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'EUR', 'locale': 'en'}, 'id': 'call_ovSx5xrlNnk7y7pLKfTxBqxC', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 1929, 'total_tokens': 3158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1856}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T20:00:00.000Z",\n      "local": "2026-03-31T13:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T11:50:00.000Z",\n      "local": "2026-04-02T20:50:00.000"\n    },\n    "totalDurationInSeconds": 143400,\n    "durationInSeconds": 143400,\n    "price": 350,\n    "deepLink": "https://on.kiwi.com/aPSblC",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-04-01T10:55:00.000Z",\n          "local": "2026-04-01T18:55:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T07:20:00.000Z",\n          "local": "2026-04-02T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T02:32:00.000Z",\n      "local": "2026-03-31T19:32:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T05:25:00.000Z",\n      "local": "2026-04-02T14:25:00.000"\n    },\n    "totalDurationInSeconds": 96780,\n    "durationInSeconds": 96780,\n    "price": 381,\n    "deepLink": "https://on.kiwi.com/OPxdps",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "LAS",\n        "city": "Las Vegas",\n        "cityCode": "LAS",\n        "arrival": {\n          "utc": "2026-04-01T04:14:00.000Z",\n          "local": "2026-03-31T21:14:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T08:01:00.000Z",\n          "local": "2026-04-01T01:01:00.000"\n        }\n      },\n      {\n        "at": "IAH",\n        "city": "Houston",\n        "cityCode": "HOU",\n        "arrival": {\n          "utc": "2026-04-01T10:52:00.000Z",\n          "local": "2026-04-01T05:52:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T15:25:00.000Z",\n          "local": "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T20:00:00.000Z",\n      "local": "2026-03-31T13:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T01:10:00.000Z",\n      "local": "2026-04-02T10:10:00.000"\n    },\n    "totalDurationInSeconds": 105000,\n    "durationInSeconds": 105000,\n    "price": 451,\n    "deepLink": "https://on.kiwi.com/iZMUrX",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-04-01T10:55:00.000Z",\n          "local": "2026-04-01T18:55:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T12:30:00.000Z",\n          "local": "2026-04-01T20:30:00.000"\n        }\n      },\n      {\n        "at": "MNL",\n        "city": "Manila",\n        "cityCode": "MNL",\n        "arrival": {\n          "utc": "2026-04-01T14:55:00.000Z",\n          "local": "2026-04-01T22:55:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T20:35:00.000Z",\n          "local": "2026-04-02T04:35:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T08:05:00.000Z",\n      "local": "2026-03-31T01:05:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:00:00.000Z",\n      "local": "2026-04-01T19:00:00.000"\n    },\n    "totalDurationInSeconds": 93300,\n    "durationInSeconds": 93300,\n    "price": 527,\n    "deepLink": "https://on.kiwi.com/MucFI8",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival":  ...
#               AIMessage(content='Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026.\n\nCheapest direct option\n- Route: SFO → NRT\n- Times (local): 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m)\n- Cabin: Economy\n- Return: —\n- Price: 572 EUR\n- Book: https://on.kiwi.com/Cm2Frg\n\nShortest direct option\n- Route: SFO → NRT\n- Times (local): 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m)\n- Cabin: Economy\n- Return: —\n- Price: 572 EUR\n- Book: https://on.kiwi.com/Cm2Frg\n\nOther direct option\n- Route: SFO → NRT\n- Times (local): 31/03/2026 11:40 → 01/04/2026 15:00 (11h 20m)\n- Cabin: Economy\n- Return: —\n- Price: 876 EUR\n- Book: https://on.kiwi.com/NjfrVn\n\nRecommendation\nBest value: The cheapest direct flight at 572 EUR (SFO 31/03 16:45 to NRT 01/04 20:00, 11h 15m, Economy).\n\nHave a great trip! Fun fact: Tokyo is known for its incredibly punctual trains and efficient transit network—they’re famous for arriving and departing on exact times to the minute.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4583, 'prompt_tokens': 6092, 'total_tokens': 10675, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 4224, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8q46ZrUWZWPM0z53QrJBr9L34Nwo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c57c6-341e-7153-95a4-65158bcf4ce8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6092, 'output_tokens': 4583, 'total_tokens': 10675, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 4224}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026.
#
# Cheapest direct option
# - Route: SFO → NRT
# - Times (local): 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m)
# - Cabin: Economy
# - Return: —
# - Price: 572 EUR
# - Book: https://on.kiwi.com/Cm2Frg
#
# Shortest direct option
# - Route: SFO → NRT
# - Times (local): 31/03/2026 16:45 → 01/04/2026 20:00 (11h 15m)
# - Cabin: Economy
# - Return: —
# - Price: 572 EUR
# - Book: https://on.kiwi.com/Cm2Frg
#
# Other direct option
# - Route: SFO → NRT
# - Times (local): 31/03/2026 11:40 → 01/04/2026 15:00 (11h 20m)
# - Cabin: Economy
# - Return: —
# - Price: 876 EUR
# - Book: https://on.kiwi.com/NjfrVn
#
# Recommendation
# Best value: The cheapest direct flight at 572 EUR (SFO 31/03 16:45 to NRT 01/04 20:00, 11h 15m, Economy).
#
# Have a great trip! Fun fact: Tokyo is known for its incredibly punctual trains and efficient transit network—they’re famous for arriving and departing on exact times to the minute.
